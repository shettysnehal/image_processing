# %%
import cv2
from insightface.app import FaceAnalysis
from matplotlib import pyplot as plt

# %%
faceapp = FaceAnalysis(name='buffalo_sc',root='insightface_model', providers = ['CPUExecutionProvider'])
faceapp.prepare(ctx_id = 0, det_size=(640,640), det_thresh = 0.5)
# Out:
# download_path: insightface_model\models\buffalo_sc
# ...
# 100%|██████████| 14619/14619 [00:03<00:00, 3795.64KB/s]
# Applied providers: ['CPUExecutionProvider'], with options: {'CPUExecutionProvider': {}}
# find model: insightface_model\models\buffalo_sc\det_500m.onnx detection [1, 3, '?', '?'] 127.5 128.0
# Applied providers: ['CPUExecutionProvider'], with options: {'CPUExecutionProvider': {}}
# find model: insightface_model\models\buffalo_sc\w600k_mbf.onnx recognition ['None', 3, 112, 112] 127.5 127.5
# set det-size: (640, 640)

# %%
# Load the image
image_path = 'face1.jpg'  # Replace with your image path
image = cv2.imread(image_path)
image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)  # Convert to RGB

# Detect faces in the image
faces = faceapp.get(image_rgb)

# Draw bounding boxes on detected faces
for face in faces:
    bbox = face.bbox.astype(int)  # Get bounding box coordinates
    x1, y1, x2, y2 = bbox
    cv2.rectangle(image_rgb, (x1, y1), (x2, y2), (255, 0, 0), 2)  # Draw rectangle

# Display the image with detected faces
plt.imshow(image_rgb)
plt.axis('off')
plt.title('Detected Faces')
plt.show()

# %%
# Load the image
image_path = 'face1.jpg'  # Replace with your image path
image = cv2.imread(image_path)
image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)  # Convert to RGB

# Detect faces in the image
faces = faceapp.get(image_rgb)

# Draw bounding boxes and display additional information
for face in faces:
    print(face.bbox)
    print(face.sex)
# Out:
# [315.90164 152.26903 428.1594  301.858  ]
# None
# [1777.9069   160.79703 1884.7837   294.1971 ]
# None
# [ 899.13983  459.7438  1007.7395   604.95306]
# None
# [2114.682    186.25548 2223.6086   330.754  ]
# None
# [224.02036 349.38696 349.41043 518.2485 ]
# None
# [1980.3727  364.9653 2095.557   522.9196]
# None
# [1156.153    676.76086 1278.7294   847.76636]
# None
# [1003.0717   158.88449 1117.5845   305.30466]
# None
# [338.45227 681.32965 470.2208  853.9721 ]
# None
# [717.03613 703.78894 837.03284 847.08417]
# None
# [614.83575 121.70398 723.39343 270.18076]
# None
# [1587.3651   688.87225 1710.5626   839.24835]
# None
# [2014.8699   669.88275 2142.598    844.53973]
# None
# [1550.4292   349.02707 1668.1292   501.7414 ]
# None
# [1230.521    459.08664 1332.8488   589.7462 ]
# None
# [1424.8572   192.47324 1532.7089   343.5904 ]
# None
# [634.21246 375.58154 748.06274 538.9553 ]
# None
